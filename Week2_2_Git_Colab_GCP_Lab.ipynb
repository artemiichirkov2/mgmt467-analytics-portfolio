# %% [markdown]
# # Week 2.2 Lab: GitHub + Colab + GCP Integration

# %% [markdown]
# In this guided lab, you will practice setting up your **team workflow** by connecting GitHub, Google Colab, Google Drive,
# and Google Cloud Platform (GCP). By the end, you will have a working notebook saved in your team repo and authenticated to GCP.
#
# **Learning Objectives:**
# - Create and configure a GitHub account (if not already done).
# - Create or join your **team repository** on GitHub.
# - Connect Colab to Google Drive for data and notebook persistence.
# - Authenticate Colab to access GCP services (BigQuery, Storage).
# - Save your Colab notebook to your GitHub repository.

# %% [markdown]
# ## 1. GitHub Account & Team Repository

# %% [markdown]
# 1. Go to [https://github.com](https://github.com) and create an account (if you don’t already have one).
# 2. One teammate should create a new repository (e.g., `MGMT467_TeamX`), set it to **Private**, and add collaborators.
# 3. Each team member should **accept the invite** to the repo.
# 4. Confirm by cloning the repo locally or simply viewing it online.
#
# :bulb: Later labs will rely on this shared repo for collaboration.

# %% [markdown]
# ## 2. Connect Colab to Google Drive

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Check contents (optional)
# !ls /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 'AI Automation | YR.gdoc'
# 'Anna.Money Tables.gsheet'
# 'Artem common app final.gdoc'
#  Artemii_Chirkov_Resume.pdf
# 'BAIM Association - Official Callout Recap.pdf'
# 'Case 1: Black and Decker (A).gdoc'
#  Chirkov_Argumentative_Essay_FirstDraft.gdoc
# 'Colab Notebooks'
# 'Competitive Analysis Plan | Artemii Chirkov.gdoc'
# 'Deal Sharing Telegram Bot | YR.gdoc'
# 'ECON 251.gdoc'
# 'Georgia Tech supplement - Artem Chirkov.gdoc'
# 'H1 2025 | Playground.gslides'
# 'High-level analysis of 6 companies.gdoc'
# 'HTGF Application Readiness.gdoc'
# 'ILS Group Assignment | Answers to the questions.gdoc'
# 'MGMT 324 | Prof.gdoc'
#  MGMT335_MEMO.gdoc
#  MGMT467
# 'PosterPresentations.com-Virtual(4.3-Ratio)-Template-Winston (1).mp4'
# 'PosterPresentations.com-Virtual(4.3-Ratio)-Template-Winston (2).mp4'
# 'PosterPresentations.com-Virtual(4.3-Ratio)-Template-Winston.mp4'
# 'Project Report: Wiley Dining Court.gdoc'
# 'Recommendation Letter.gdoc'
# 'ScreenRecording_08-09-2025 03-40-01_1.mp4'
# 'Screenshot 2024-07-17 at 01.04.32.png'
# 'Team Expectations & Planning Worksheet (10 points).gdoc'
# 'Thoughts for essays.gdoc'
#  Universities.gdoc
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'Wiley Dining Court Analysis.gslides'
# 'Work Report | Artemii Chirkov (1).gsheet'
# 'Work Report | Artemii Chirkov.gsheet'
# 'XTIX  vs. Competitors.gsheet'
# 'YR App Competitive Analysis.gsheet'
# 'YR App Core Features vs. Competitors.gsheet'
# 'Годовой семейный бюджет.gsheet'
# 'Копия Artem Chirkov - Common App - Draft 1 - Essay Review Team.gdoc'
# 'Месячный бюджет.gsheet'
# 'Новая таблица.gsheet'
# 'Новый документ.gdoc'
#  Полис.pdf
# 'Русский язык. Вариант 2.pdf'
# 'Снимок экрана 2023-05-10 в 08.35.38.png'
# 'Список дел.gsheet'

# %% [markdown]
# ## 3. Authenticate GCP in Colab

# %%
from google.colab import auth
auth.authenticate_user()

print("Authenticated to GCP successfully!")
# Out:
# Authenticated to GCP successfully!

# %% [markdown]
# Once authenticated, you can access BigQuery and other GCP services from this notebook.

# %% [markdown]
# ## 4. Run a BigQuery Sanity Query

# %%
from google.cloud import bigquery

# Create a BigQuery client
client = bigquery.Client(project="mgmt-467-47889")

# Simple test query: public dataset
query = "SELECT name, SUM(number) as total FROM `bigquery-public-data.usa_names.usa_1910_2013` GROUP BY name ORDER BY total DESC LIMIT 5"
results = client.query(query).to_dataframe()

results
# Out:
#       name    total
# 0    James  4942431
# 1     John  4834422
# 2   Robert  4718787
# 3  Michael  4297230
# 4  William  3822209

# %% [markdown]
# ## 5. Save Notebook to GitHub

# %% [markdown]
# To push from Colab to GitHub, you can use a **personal access token (PAT)**.
#
# **Steps:**
# 1. On GitHub, go to **Settings → Developer settings → Personal access tokens (classic)**.
# 2. Generate a token with `repo` permissions (set expiry to ~7 days for safety).
# 3. In Colab, use the snippet below to push your notebook back to GitHub.
#
# :warning: Do **NOT** hardcode tokens in notebooks. Use `getpass` to input securely.

# %%
import os
from getpass import getpass

# Enter your GitHub credentials
username = "artemiichirkov2"
token = getpass("Token: ")
repo = "mgmt467-analytics-portfolio"  # e.g., MGMT467_TeamX
notebook_filename = "Week2_2_Git_Colab_GCP_Lab.ipynb"
notebook_path = "/content/drive/MyDrive/MGMT467/Labs/" + notebook_filename # Corrected path

# Set git credentials globally
# !git config --global user.name "{username}"
# !git config --global user.email "{username}@users.noreply.github.com"

# Clone the repo if it doesn't exist
if not os.path.exists(repo):
  # !git clone https://{username}:{token}@github.com/{username}/{repo}.git

# Change directory to the repo
# %cd {repo}/Labs

# Copy notebook into repo
# !cp "{notebook_path}" .

# Commit and push
# !git add . && git commit -m "Added Week 2.2 Lab notebook" && git push
# Out:
# Token: ··········
# fatal: Too many arguments.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     --reject-shallow      don't clone shallow repository
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     --recursive ...       alias of --recurse-submodules
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
#     --reference <repo>    reference repository
#     --reference-if-able <repo>
#                           reference repository
#     --dissociate          use --reference only while cloning
#     -o, --origin <name>   use <name> instead of 'origin' to track upstream
#     -b, --branch <branch>
#                           checkout <branch> instead of the remote's HEAD
#     -u, --upload-pack <path>
#                           path to git-upload-pack on the remote
#     --depth <depth>       create a shallow clone of that depth
#     --shallow-since <time>
#                           create a shallow clone since a specific time
#     --shallow-exclude <revision>
#                           deepen history of shallow clone, excluding rev
#     --single-branch       clone only one branch, HEAD or --branch
#     --no-tags             don't clone any tags, and make later fetches not to follow them
#     --shallow-submodules  any cloned submodules will be shallow
#     --separate-git-dir <gitdir>
#                           separate git dir from working tree
#     -c, --config <key=value>
#                           set config inside the new repository
#     --server-option <server-specific>
#                           option to transmit
#     -4, --ipv4            use IPv4 addresses only
#     -6, --ipv6            use IPv6 addresses only
#     --filter <args>       object filtering
#     --remote-submodules   any cloned submodules will use their remote-tracking branch
#     --sparse              initialize sparse-checkout file to include only files at root
#
# [Errno 2] No such file or directory: 'mgmt467-analytics-portfolio/Labs'
# /content/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio
# [main 50130f2] Added Week 2.2 Lab notebook
#  1 file changed, 1 insertion(+), 1 deletion(-)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 634 bytes | 634.00 KiB/s, done.
# Total 3 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/artemiichirkov2/mgmt467-analytics-portfolio.git
#    d8e9f4a..50130f2  main -> main

# %% [markdown]
# ## ✅ Exit Ticket

# %% [markdown]
# Before you leave, make sure you have:
# - [ ] Mounted Google Drive in Colab
# - [ ] Authenticated to GCP successfully
# - [ ] Run the BigQuery sanity check
# - [ ] Saved your notebook to your team GitHub repo
#
# Upload your GitHub repo link to Brightspace as proof of completion.

# %%
# !ls -R /content/
# Out:
# /content/:
# drive  mgmt467-analytics-portfolio  sample_data
#
# /content/drive:
# MyDrive
#
# /content/drive/MyDrive:
# 'AI Automation | YR.gdoc'
# 'Anna.Money Tables.gsheet'
# 'Artem common app final.gdoc'
#  Artemii_Chirkov_Resume.pdf
# 'BAIM Association - Official Callout Recap.pdf'
# 'Case 1: Black and Decker (A).gdoc'
#  Chirkov_Argumentative_Essay_FirstDraft.gdoc
# 'Colab Notebooks'
# 'Competitive Analysis Plan | Artemii Chirkov.gdoc'
# 'Deal Sharing Telegram Bot | YR.gdoc'
# 'ECON 251.gdoc'
# 'Georgia Tech supplement - Artem Chirkov.gdoc'
# 'H1 2025 | Playground.gslides'
# 'High-level analysis of 6 companies.gdoc'
# 'HTGF Application Readiness.gdoc'
# 'ILS Group Assignment | Answers to the questions.gdoc'
# 'MGMT 324 | Prof.gdoc'
#  MGMT335_MEMO.gdoc
#  MGMT467
# 'PosterPresentations.com-Virtual(4.3-Ratio)-Template-Winston (1).mp4'
# 'PosterPresentations.com-Virtual(4.3-Ratio)-Template-Winston (2).mp4'
# 'PosterPresentations.com-Virtual(4.3-Ratio)-Template-Winston.mp4'
# 'Project Report: Wiley Dining Court.gdoc'
# 'Recommendation Letter.gdoc'
# 'ScreenRecording_08-09-2025 03-40-01_1.mp4'
# 'Screenshot 2024-07-17 at 01.04.32.png'
# 'Team Expectations & Planning Worksheet (10 points).gdoc'
# 'Thoughts for essays.gdoc'
#  Universities.gdoc
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'Wiley Dining Court Analysis.gslides'
# 'Work Report | Artemii Chirkov (1).gsheet'
# 'Work Report | Artemii Chirkov.gsheet'
# 'XTIX  vs. Competitors.gsheet'
# 'YR App Competitive Analysis.gsheet'
# 'YR App Core Features vs. Competitors.gsheet'
# 'Годовой семейный бюджет.gsheet'
# 'Копия Artem Chirkov - Common App - Draft 1 - Essay Review Team.gdoc'
# 'Месячный бюджет.gsheet'
# 'Новая таблица.gsheet'
# 'Новый документ.gdoc'
#  Полис.pdf
# 'Русский язык. Вариант 2.pdf'
# 'Снимок экрана 2023-05-10 в 08.35.38.png'
# 'Список дел.gsheet'
#
# '/content/drive/MyDrive/Colab Notebooks':
# Finance_Analytics_Course  Group16_Final_project_ECON373.ipynb  MGMT467
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course':
# Data			   Session_4_Time_Series
# Documentation		   Session_5_Portfolio_Metrics
# Session_0_Setup		   Session_6_Building_Optimal_Portfolios
# Session_1_Total_Return	   Session_7_Asset_Allocation_and_Rebalancing
# Session_2_Data_Collection  Session_8_Risk_Management
# Session_3_Data_Cleaning
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Data':
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Documentation':
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Session_0_Setup':
# Finance_Analytics_Setup.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Session_1_Total_Return':
# Session1.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Session_2_Data_Collection':
# Session2.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Session_3_Data_Cleaning':
# Session3.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Session_4_Time_Series':
# Session4.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Session_5_Portfolio_Metrics':
# Session5.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Session_6_Building_Optimal_Portfolios':
# Session6.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Session_7_Asset_Allocation_and_Rebalancing':
# Session7.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks/Finance_Analytics_Course/Session_8_Risk_Management':
# Session8.ipynb
#
# '/content/drive/MyDrive/Colab Notebooks/MGMT467':
# Assignments  Data  Exports  Final_Project  Labs
#
# '/content/drive/MyDrive/Colab Notebooks/MGMT467/Assignments':
#
# '/content/drive/MyDrive/Colab Notebooks/MGMT467/Data':
#
# '/content/drive/MyDrive/Colab Notebooks/MGMT467/Exports':
#
# '/content/drive/MyDrive/Colab Notebooks/MGMT467/Final_Project':
#
# '/content/drive/MyDrive/Colab Notebooks/MGMT467/Labs':
# Lab0_Colab_Drive_Setup.ipynb
#
# /content/drive/MyDrive/MGMT467:
# Assignments  Data  Exports  Final_Project  Labs
#
# /content/drive/MyDrive/MGMT467/Assignments:
#
# /content/drive/MyDrive/MGMT467/Data:
# hello1.csv  hello2.csv	hello.csv
#
# /content/drive/MyDrive/MGMT467/Exports:
#
# /content/drive/MyDrive/MGMT467/Final_Project:
#
# /content/drive/MyDrive/MGMT467/Labs:
# Lab0_Colab_Drive_Setup.ipynb  Week2_2_Git_Colab_GCP_Lab.ipynb
# Lab1_AI_Assisted_SQL.ipynb
#
# /content/mgmt467-analytics-portfolio:
# Assignments  Final_Project  Labs  mgmt467-analytics-portfolio  README.md
#
# /content/mgmt467-analytics-portfolio/Assignments:
#
# /content/mgmt467-analytics-portfolio/Final_Project:
#
# /content/mgmt467-analytics-portfolio/Labs:
# Lab1_AI_Assisted_SQL.ipynb
#
# /content/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio:
# Assignments  Final_Project  Labs  mgmt467-analytics-portfolio  README.md
#
# /content/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/Assignments:
#
# /content/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/Final_Project:
#
# /content/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/Labs:
# Lab1_AI_Assisted_SQL.ipynb
#
# /content/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio:
# Assignments  Final_Project  Labs  README.md
#
# /content/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/Assignments:
#
# /content/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/Final_Project:
#
# /content/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/mgmt467-analytics-portfolio/Labs:
# Lab1_AI_Assisted_SQL.ipynb
#
# /content/sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md
